# %%
import numpy as np
import pandas as pd

# ? Init Lib
lib_3 = pd.Series(['numpy            ', 'pandas        ', 'pot;ato'])

# %% [markdown]
# <div align="center">
#
# # ----------------- Part 1 ------------------- #
# </div>

# %%
# * One liner -> Single Line exe
lib_3.str.strip().str.replace(';', '').str.upper()
# Out:
# 0     NUMPY
# 1    PANDAS
# 2    POTATO
# dtype: object

# %%
# * Function to cleanse the string by applying methods
def sanitize(ser):
    ser = ser.strip()
    ser = ser.replace(';', '')
    ser = ser.upper()
    return ser

lib_3.apply(sanitize)
# Out:
# 0     NUMPY
# 1    PANDAS
# 2    POTATO
# dtype: object

# %% [markdown]
# <div align="center">
#
# # ----------------- Part 2 ------------------- #
# </div>

# %%
# * Init CSV File
df = pd.read_csv('./imdb_top_1000_New-4.csv')
df
# Out:
#               Series_Title Released_Year Certificate  Runtime  Runtime2  \
# 0                 Oldeuboi          2003           A  101 min       101
# 1             Serbuan maut          2011           A  101 min       101
# 2         Enter the Dragon          1973           A  102 min       102
# 3              Dirty Harry          1971           A  102 min       102
# 4    The French Connection          1971           A  104 min       104
# ..                     ...           ...         ...      ...       ...
# 896    Hiroshima mon amour          1959          UA   90 min        90
# 897                Gravity          2013          UA   91 min        91
# 898   Pink Floyd: The Wall          1982          UA   95 min        95
# 899        Ivanovo detstvo          1962          UA   95 min        95
# 900               Lifeboat          1944          UA   97 min        97
#
#       Genre  IMDB_Rating  No_of_Votes      Gross
# 0    Action          8.4       515451     707481
# ...

# %%
# * Info about the csv
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 901 entries, 0 to 900
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Series_Title   901 non-null    object
#  1   Released_Year  901 non-null    object
#  2   Certificate    901 non-null    object
#  3   Runtime        901 non-null    object
#  4   Runtime2       901 non-null    int64
#  5   Genre          901 non-null    object
#  6   IMDB_Rating    901 non-null    float64
#  7   No_of_Votes    901 non-null    int64
#  8   Gross          901 non-null    int64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 63.5+ KB

# %%
# * Check the top 8 values
df.head(8)
# Out:
#                           Series_Title Released_Year Certificate  Runtime  \
# 0                             Oldeuboi          2003           A  101 min
# 1                         Serbuan maut          2011           A  101 min
# 2                     Enter the Dragon          1973           A  102 min
# 3                          Dirty Harry          1971           A  102 min
# 4                The French Connection          1971           A  104 min
# 5  Lock, Stock and Two Smoking Barrels          1998           A  107 min
# 6                             Predator          1987           A  107 min
# 7                 The Bourne Supremacy          2004           A  108 min
#
#    Runtime2   Genre  IMDB_Rating  No_of_Votes      Gross
# 0       101  Action          8.4       515451     707481
# 1       101  Action          7.6       190531    4105123
# 2       102  Action          7.7        96561   25000000
# 3       102  Action          7.7       143292   35900000
# ...

# %%
# * Give a report on the csv
df.describe().transpose()
# Out:
#              count          mean           std      min        25%  \
# Runtime2     901.0  1.237725e+02  2.788991e+01     45.0      104.0
# IMDB_Rating  901.0  7.948391e+00  2.772287e-01      7.6        7.7
# No_of_Votes  901.0  2.852698e+05  3.357608e+05  25088.0    58314.0
# Gross        901.0  6.463583e+07  1.064970e+08   1305.0  2537520.0
#
#                     50%         75%          max
# Runtime2          120.0       137.0        321.0
# IMDB_Rating         7.9         8.1          9.3
# No_of_Votes    143434.0    400049.0    2343110.0
# Gross        20186659.0  75605492.0  936662225.0

# %%
# * Display a specific column
a = df['Released_Year']
type(a)
# Out:
# pandas.core.series.Series

# %%
cols = ['Runtime2', 'IMDB_Rating']
df[cols]
# Out:
#      Runtime2  IMDB_Rating
# 0         101          8.4
# 1         101          7.6
# 2         102          7.7
# 3         102          7.7
# 4         104          7.7
# ..        ...          ...
# 896        90          7.9
# 897        91          7.7
# 898        95          8.1
# 899        95          8.1
# 900        97          7.6
#
# [901 rows x 2 columns]

# %%
df[['Runtime2', 'IMDB_Rating']]
# Out:
#      Runtime2  IMDB_Rating
# 0         101          8.4
# 1         101          7.6
# 2         102          7.7
# 3         102          7.7
# 4         104          7.7
# ..        ...          ...
# 896        90          7.9
# 897        91          7.7
# 898        95          8.1
# 899        95          8.1
# 900        97          7.6
#
# [901 rows x 2 columns]

# %%
# * Maths Operations between columns
df['IMDB_Rating'] + df['Gross']
# Out:
# 0         707489.4
# 1        4105130.6
# 2       25000007.7
# 3       35900007.7
# 4       15630717.7
#           ...
# 896        88307.9
# 897    274092712.7
# 898     22244215.1
# 899       102629.1
# 900     13780431.6
# Length: 901, dtype: float64

# %%
# * Create column based on another column
df['Runtime in hours'] = np.round(df['Runtime2'] / 60, 2)
df
# Out:
#               Series_Title Released_Year Certificate  Runtime  Runtime2  \
# 0                 Oldeuboi          2003           A  101 min       101
# 1             Serbuan maut          2011           A  101 min       101
# 2         Enter the Dragon          1973           A  102 min       102
# 3              Dirty Harry          1971           A  102 min       102
# 4    The French Connection          1971           A  104 min       104
# ..                     ...           ...         ...      ...       ...
# 896    Hiroshima mon amour          1959          UA   90 min        90
# 897                Gravity          2013          UA   91 min        91
# 898   Pink Floyd: The Wall          1982          UA   95 min        95
# 899        Ivanovo detstvo          1962          UA   95 min        95
# 900               Lifeboat          1944          UA   97 min        97
#
#       Genre  IMDB_Rating  No_of_Votes      Gross  Runtime in hours
# ...

# %%
# * Drop a column in a table
df.drop('Runtime in hours', axis=1, inplace=True)
df
# Out:
#               Series_Title Released_Year Certificate  Runtime  Runtime2  \
# 0                 Oldeuboi          2003           A  101 min       101
# 1             Serbuan maut          2011           A  101 min       101
# 2         Enter the Dragon          1973           A  102 min       102
# 3              Dirty Harry          1971           A  102 min       102
# 4    The French Connection          1971           A  104 min       104
# ..                     ...           ...         ...      ...       ...
# 896    Hiroshima mon amour          1959          UA   90 min        90
# 897                Gravity          2013          UA   91 min        91
# 898   Pink Floyd: The Wall          1982          UA   95 min        95
# 899        Ivanovo detstvo          1962          UA   95 min        95
# 900               Lifeboat          1944          UA   97 min        97
#
#       Genre  IMDB_Rating  No_of_Votes      Gross
# 0    Action          8.4       515451     707481
# ...

# %%
# * Set the index to another column
df = df.set_index('Series_Title')

# %%
df
# Out:
#                       Released_Year Certificate  Runtime  Runtime2   Genre  \
# Series_Title
# Oldeuboi                       2003           A  101 min       101  Action
# Serbuan maut                   2011           A  101 min       101  Action
# Enter the Dragon               1973           A  102 min       102  Action
# Dirty Harry                    1971           A  102 min       102  Action
# The French Connection          1971           A  104 min       104  Action
# ...                             ...         ...      ...       ...     ...
# Hiroshima mon amour            1959          UA   90 min        90   Drama
# Gravity                        2013          UA   91 min        91   Drama
# Pink Floyd: The Wall           1982          UA   95 min        95   Drama
# Ivanovo detstvo                1962          UA   95 min        95   Drama
# Lifeboat                       1944          UA   97 min        97   Drama
#
# ...

# %%
# * View Column Through Index Call
df.iloc[0]
# Out:
# Released_Year       2003
# Certificate            A
# Runtime          101 min
# Runtime2             101
# Genre             Action
# IMDB_Rating          8.4
# No_of_Votes       515451
# Gross             707481
# Name: Oldeuboi, dtype: object

# %%
# * View Column Through String Call
df.loc['Predator']
# Out:
# Released_Year        1987
# Certificate             A
# Runtime           107 min
# Runtime2              107
# Genre              Action
# IMDB_Rating           7.8
# No_of_Votes        371387
# Gross            59735548
# Name: Predator, dtype: object

# %%
# * View Table Using Slicing Method
df.iloc[4:15]
# Out:
#                                     Released_Year Certificate  Runtime  \
# Series_Title
# The French Connection                        1971           A  104 min
# Lock, Stock and Two Smoking Barrels          1998           A  107 min
# Predator                                     1987           A  107 min
# The Bourne Supremacy                         2004           A  108 min
# End of Watch                                 2012           A  109 min
# Lethal Weapon                                1987           A  109 min
# Léon                                         1994           A  110 min
# Yôjinbô                                      1961           A  110 min
# Gongdong gyeongbi guyeok JSA                 2000           A  110 min
# Goldfinger                                   1964           A  110 min
# Bonnie and Clyde                             1967           A  111 min
#
#                                      Runtime2   Genre  IMDB_Rating  \
# Series_Title
# ...

# %%
# * Drop Row 
df.drop('Léon')
df
# Out:
#                       Released_Year Certificate  Runtime  Runtime2   Genre  \
# Series_Title
# Oldeuboi                       2003           A  101 min       101  Action
# Serbuan maut                   2011           A  101 min       101  Action
# Enter the Dragon               1973           A  102 min       102  Action
# Dirty Harry                    1971           A  102 min       102  Action
# The French Connection          1971           A  104 min       104  Action
# ...                             ...         ...      ...       ...     ...
# Hiroshima mon amour            1959          UA   90 min        90   Drama
# Gravity                        2013          UA   91 min        91   Drama
# Pink Floyd: The Wall           1982          UA   95 min        95   Drama
# Ivanovo detstvo                1962          UA   95 min        95   Drama
# Lifeboat                       1944          UA   97 min        97   Drama
#
# ...

# %%
# * Reset the index to the original index
df = df.reset_index()
df
# Out:
#               Series_Title Released_Year Certificate  Runtime  Runtime2  \
# 0                 Oldeuboi          2003           A  101 min       101
# 1             Serbuan maut          2011           A  101 min       101
# 2         Enter the Dragon          1973           A  102 min       102
# 3              Dirty Harry          1971           A  102 min       102
# 4    The French Connection          1971           A  104 min       104
# ..                     ...           ...         ...      ...       ...
# 896    Hiroshima mon amour          1959          UA   90 min        90
# 897                Gravity          2013          UA   91 min        91
# 898   Pink Floyd: The Wall          1982          UA   95 min        95
# 899        Ivanovo detstvo          1962          UA   95 min        95
# 900               Lifeboat          1944          UA   97 min        97
#
#       Genre  IMDB_Rating  No_of_Votes      Gross
# 0    Action          8.4       515451     707481
# ...

# %%
# * Conditional Check -> Boolean View
df['IMDB_Rating'].head(5) > 8
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# Name: IMDB_Rating, dtype: bool

# %%
# * Conditional Check -> Table View 
df[df['IMDB_Rating'] > 8]
# Out:
#                             Series_Title Released_Year Certificate  Runtime  \
# 0                               Oldeuboi          2003           A  101 min
# 5    Lock, Stock and Two Smoking Barrels          1998           A  107 min
# 10                                  Léon          1994           A  110 min
# 11                               Yôjinbô          1961           A  110 min
# 18                            White Heat          1949           A  114 min
# ..                                   ...           ...         ...      ...
# 877                                 Pink          2016          UA  136 min
# 881                         Forrest Gump          1994          UA  142 min
# 892                           Kis Uykusu          2014          UA  196 min
# 898                 Pink Floyd: The Wall          1982          UA   95 min
# 899                      Ivanovo detstvo          1962          UA   95 min
#
# ...

# %%
# * Equals Conditional
df[df['Certificate'] == 'A']
# Out:
#               Series_Title Released_Year Certificate  Runtime  Runtime2  \
# 0                 Oldeuboi          2003           A  101 min       101
# 1             Serbuan maut          2011           A  101 min       101
# 2         Enter the Dragon          1973           A  102 min       102
# 3              Dirty Harry          1971           A  102 min       102
# 4    The French Connection          1971           A  104 min       104
# ..                     ...           ...         ...      ...       ...
# 702          Trainspotting          1996           A   93 min        93
# 703      In a Lonely Place          1950           A   94 min        94
# 704  El ángel exterminador          1962           A   95 min        95
# 705    Det sjunde inseglet          1957           A   96 min        96
# 706             Detachment          2011           A   98 min        98
#
#       Genre  IMDB_Rating  No_of_Votes     Gross
# 0    Action          8.4       515451    707481
# ...

# %%
# * Double Conditional Statement -> Use Symbol
df[(df['Certificate'] == 'A') & (df['IMDB_Rating'] > 8)]
# Out:
#                             Series_Title Released_Year Certificate  Runtime  \
# 0                               Oldeuboi          2003           A  101 min
# 5    Lock, Stock and Two Smoking Barrels          1998           A  107 min
# 10                                  Léon          1994           A  110 min
# 11                               Yôjinbô          1961           A  110 min
# 18                            White Heat          1949           A  114 min
# ..                                   ...           ...         ...      ...
# 699                        Jungfrukällan          1960           A   89 min
# 701                   Viskningar och rop          1972           A   91 min
# 702                        Trainspotting          1996           A   93 min
# 704                El ángel exterminador          1962           A   95 min
# 705                  Det sjunde inseglet          1957           A   96 min
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 901 entries, 0 to 900
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Series_Title   901 non-null    object
#  1   Released_Year  901 non-null    object
#  2   Certificate    901 non-null    object
#  3   Runtime        901 non-null    object
#  4   Runtime2       901 non-null    int64
#  5   Genre          901 non-null    object
#  6   IMDB_Rating    901 non-null    float64
#  7   No_of_Votes    901 non-null    int64
#  8   Gross          901 non-null    int64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 63.5+ KB

# %%
# * Use Apply to slice the last 2 digits
def last_digits(num):
    return str(num)[-2:]


df['Gross'].apply(last_digits)
# Out:
# 0      81
# 1      23
# 2      00
# 3      00
# 4      10
#        ..
# 896    00
# 897    05
# 898    07
# 899    21
# 900    24
# Name: Gross, Length: 901, dtype: object

# %%
# * Create Column and apply function
df['last_to_digits_in_gross'] = df['Gross'].apply(last_digits)

df['last_to_digits_in_gross']
# Out:
# 0      81
# 1      23
# 2      00
# 3      00
# 4      10
#        ..
# 896    00
# 897    05
# 898    07
# 899    21
# 900    24
# Name: last_to_digits_in_gross, Length: 901, dtype: object

# %%
df.sort_values('IMDB_Rating', ascending=False)
# Out:
#                  Series_Title Released_Year Certificate  Runtime  Runtime2  \
# 675  The Shawshank Redemption          1994           A  142 min       142
# 567             The Godfather          1972           A  175 min       175
# 610              12 Angry Men          1957           U   96 min        96
# 570    The Godfather: Part II          1974           A  202 min       202
# 149           The Dark Knight          2008          UA  152 min       152
# ..                        ...           ...         ...      ...       ...
# 36            Minority Report          2002           A  145 min       145
# 16       Escape from Alcatraz          1979           A  112 min       112
# 900                  Lifeboat          1944          UA   97 min        97
# 20                        300          2006           A  117 min       117
# 21                    Sicario          2015           A  121 min       121
#
# ...

# %%
# * Sort Values based on priority
df.sort_values(['IMDB_Rating', 'No_of_Votes'], ascending=False)
# Out:
#                  Series_Title Released_Year Certificate  Runtime  Runtime2  \
# 675  The Shawshank Redemption          1994           A  142 min       142
# 567             The Godfather          1972           A  175 min       175
# 149           The Dark Knight          2008          UA  152 min       152
# 570    The Godfather: Part II          1974           A  202 min       202
# 610              12 Angry Men          1957           U   96 min        96
# ..                        ...           ...         ...      ...       ...
# 765                  Nelyubov          2017           R  127 min       127
# 852            On Golden Pond          1981          UA  109 min       109
# 268         Omohide poro poro          1991           U  118 min       118
# 900                  Lifeboat          1944          UA   97 min        97
# 393          The Long Goodbye          1973           A  112 min       112
#
# ...

# %%
df['Gross'].max()
# Out:
# np.int64(936662225)

# %%
# * Get the max value's index and find it
idx = df['Gross'].idxmax()
df.iloc[idx]
# Out:
# Series_Title               Star Wars: Episode VII - The Force Awakens
# Released_Year                                                    2015
# Certificate                                                         U
# Runtime                                                       138 min
# Runtime2                                                          138
# Genre                                                          Action
# IMDB_Rating                                                       7.9
# No_of_Votes                                                    860823
# Gross                                                       936662225
# last_to_digits_in_gross                                            25
# Name: 83, dtype: object

# %%
# * Count the number of values in a column
df['Genre'].value_counts()
# Out:
# Genre
# Drama        270
# Action       167
# Comedy       140
# Crime        104
# Biography     82
# Animation     74
# Adventure     64
# Name: count, dtype: int64

# %%
# * Drop the broken row
df[df['Released_Year'] == 'PG'].pop
df = df.drop(205, axis='index')
df
# Out:
#               Series_Title Released_Year Certificate  Runtime  Runtime2  \
# 0                 Oldeuboi          2003           A  101 min       101
# 1             Serbuan maut          2011           A  101 min       101
# 2         Enter the Dragon          1973           A  102 min       102
# 3              Dirty Harry          1971           A  102 min       102
# 4    The French Connection          1971           A  104 min       104
# ..                     ...           ...         ...      ...       ...
# 896    Hiroshima mon amour          1959          UA   90 min        90
# 897                Gravity          2013          UA   91 min        91
# 898   Pink Floyd: The Wall          1982          UA   95 min        95
# 899        Ivanovo detstvo          1962          UA   95 min        95
# 900               Lifeboat          1944          UA   97 min        97
#
#       Genre  IMDB_Rating  No_of_Votes      Gross last_to_digits_in_gross
# ...

# %%
# * Multi-level Grouping
df2 = np.round(df.groupby(['Released_Year', 'Genre']).mean(numeric_only=True), 2)
df2
# Out:
#                          Runtime2  IMDB_Rating  No_of_Votes       Gross
# Released_Year Genre
# 1921          Comedy         68.0         8.30     113314.0   5450000.0
# 1924          Action         45.0         8.20      41985.0    977375.0
# 1925          Adventure      95.0         8.20     101053.0   5450000.0
#               Drama          75.0         8.00      53054.0     50970.0
# 1926          Action         67.0         8.10      81156.0   1033895.0
# ...                           ...          ...          ...         ...
# 2019          Drama         130.0         8.00     138260.2  55838673.2
# 2020          Animation     100.0         8.10     159171.0  14677874.0
#               Biography     160.0         8.60      55291.0     12563.0
#               Comedy        109.0         7.85      72704.5   5073270.0
#               Drama         141.0         8.20      72445.5   1117805.0
#
# [376 rows x 4 columns]

# %%
# * Group Column and describe it
df.groupby('Released_Year').describe().transpose()
# Out:
# Released_Year           1921      1924          1925       1926          1927  \
# Runtime2    count        1.0       1.0  2.000000e+00        1.0  2.000000e+00
#             mean        68.0      45.0  8.500000e+01       67.0  1.235000e+02
#             std          NaN       NaN  1.414214e+01        NaN  4.171930e+01
#             min         68.0      45.0  7.500000e+01       67.0  9.400000e+01
#             25%         68.0      45.0  8.000000e+01       67.0  1.087500e+02
#             50%         68.0      45.0  8.500000e+01       67.0  1.235000e+02
#             75%         68.0      45.0  9.000000e+01       67.0  1.382500e+02
#             max         68.0      45.0  9.500000e+01       67.0  1.530000e+02
# IMDB_Rating count        1.0       1.0  2.000000e+00        1.0  2.000000e+00
#             mean         8.3       8.2  8.100000e+00        8.1  8.200000e+00
#             std          NaN       NaN  1.414214e-01        NaN  1.414214e-01
# ...

# %%
# * Display 2019
df2.loc['2019']
# Out:
#            Runtime2  IMDB_Rating  No_of_Votes         Gross
# Genre
# Action       148.67         8.10    446212.00  3.261783e+08
# Adventure    105.00         7.80     51951.00  6.831291e+06
# Animation     98.00         8.00    153969.00  2.171903e+08
# Biography    157.33         7.70    143955.67  2.799162e+07
# Comedy       135.17         8.02    356124.17  6.074641e+07
# Crime        122.00         8.50    939252.00  3.354513e+08
# Drama        130.00         8.00    138260.20  5.583867e+07

# %%
# * Multi-Level Location View
df2.xs(key='Drama', level='Genre')
# Out:
#                Runtime2  IMDB_Rating  No_of_Votes        Gross
# Released_Year
# 1925              75.00         8.00     53054.00     50970.00
# 1927             123.50         8.20    103428.50    887853.00
# 1930             152.00         8.00     57318.00   3270000.00
# 1931              70.00         7.80     65341.00   2617200.00
# 1932              64.00         7.90     42117.00   2537720.00
# ...                 ...          ...          ...          ...
# 2016             126.86         7.94    164566.29  22169114.29
# 2017             114.67         7.73    100726.83  30354342.17
# 2018             125.25         8.00    141278.75  55399759.25
# 2019             130.00         8.00    138260.20  55838673.20
# 2020             141.00         8.20     72445.50   1117805.00
#
# [82 rows x 4 columns]
